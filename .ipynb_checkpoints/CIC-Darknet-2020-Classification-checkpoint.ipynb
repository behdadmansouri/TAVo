# %% [markdown]
# # initial

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in d:\users\gautam\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in d:\users\gautam\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.1.2)
# Requirement already satisfied: numpy>=1.17.3 in d:\users\gautam\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.23.3)
# Requirement already satisfied: joblib>=1.0.0 in d:\users\gautam\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in d:\users\gautam\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\gautam\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in d:\users\gautam\appdata\local\programs\python\python310\lib\site-packages (1.9.1)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in d:\users\gautam\appdata\local\programs\python\python310\lib\site-packages (from scipy) (1.23.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Darknet.CSV", low_memory=False, parse_dates=["Timestamp"], error_bad_lines=False)
# Out:
# b'Skipping line 328: expected 85 fields, saw 125\n'

# %%
def display_all(df): # tip: you can transpose before giving input!
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        print("The shape is: ", data.shape)
        data.info()
        data.dtypes
        display(df)
        

def display_types(df):
    print(df["Level1"].unique())
    print(df["Level2"].unique())
    print(df.groupby("Level1")["Level2"].unique())
    print(df.groupby("Level1")["Level2"].nunique())

# %%
# TODO drop VPN
data.drop(["Flow ID"],axis = 1,inplace = True)
data.drop(["Src IP"],axis = 1,inplace = True)
data.drop(["Dst IP"],axis = 1,inplace = True)
data.drop(["Src Port"],axis = 1,inplace = True)
data.drop(["Dst Port"],axis = 1,inplace = True)
data.drop(["Flow Duration"],axis = 1,inplace = True)
data.drop(["Timestamp"],axis = 1,inplace = True)
# data.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=False)
# data = data.loc[:, internet_ds_test.apply(pd.Series.nunique) != 1]
data.isnull().sum()
# Out:
# Protocol                      0
# Total Fwd Packet              0
# Total Bwd packets             0
# Total Length of Fwd Packet    0
# Total Length of Bwd Packet    0
#                              ..
# Idle Std                      0
# Idle Max                      0
# Idle Min                      0
# Label                         0
# Label.1                       0
# Length: 78, dtype: int64

# %%
data.rename(columns = {"Label" : "Level1", "Label.1" : "Level2"}, inplace = True)
# data.rename({'Level2': {"AUDIO-STREAMING" : "Audio-Streaming", "Audio-streaming" : "Audio-Streaming", "Video-streaming" : "Video-Streaming", "File-transfer" : "File-Transfer"}}, inplace = True)
data['Level2'].loc[data['Level2'] == 'AUDIO-STREAMING'] = 'Audio-Streaming'
data['Level2'].loc[data['Level2'] == 'Audio-streaming'] = 'Audio-Streaming'
data['Level2'].loc[data['Level2'] == 'File-transfer'] = 'File-Transfer'
data['Level2'].loc[data['Level2'] == 'Video-streaming'] = 'Video-Streaming'
data["Level2"].unique()
# samples[real_columns] = samples[real_columns].replace([np.inf, -np.inf], np.nan)
# samples[real_columns] = samples[real_columns].dropna()
# Out:
# C:\Users\AmirHosein\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# array(['Audio-Streaming', 'Browsing', 'Chat', 'Email', 'File-Transfer',
#        'P2P', 'Video-Streaming', 'VOIP'], dtype=object)

# %% [markdown]
# # Preprocessing

# %%
display_all(data.tail())
# Out:
# The shape is:  (141530, 78)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141530 entries, 0 to 141529
# Data columns (total 78 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Protocol                    141530 non-null  int64
#  1   Total Fwd Packet            141530 non-null  int64
#  2   Total Bwd packets           141530 non-null  int64
#  3   Total Length of Fwd Packet  141530 non-null  int64
#  4   Total Length of Bwd Packet  141530 non-null  int64
#  5   Fwd Packet Length Max       141530 non-null  int64
#  6   Fwd Packet Length Min       141530 non-null  int64
#  7   Fwd Packet Length Mean      141530 non-null  float64
#  8   Fwd Packet Length Std       141530 non-null  float64
#  9   Bwd Packet Length Max       141530 non-null  int64
#  10  Bwd Packet Length Min       141530 non-null  int64
#  11  Bwd Packet Length Mean      141530 non-null  float64
#  12  Bwd Packet Length Std       141530 non-null  float64
#  13  Flow Bytes/s                141483 non-null  float64
#  14  Flow Packets/s              141530 non-null  float64
#  15  Flow IAT Mean               141530 non-null  float64
#  16  Flow IAT Std                141530 non-null  float64
#  17  Flow IAT Max                141530 non-null  int64
#  18  Flow IAT Min                141530 non-null  int64
#  19  Fwd IAT Total               141530 non-null  int64
#  20  Fwd IAT Mean                141530 non-null  float64
#  21  Fwd IAT Std                 141530 non-null  float64
#  22  Fwd IAT Max                 141530 non-null  int64
#  23  Fwd IAT Min                 141530 non-null  int64
#  24  Bwd IAT Total               141530 non-null  int64
#  25  Bwd IAT Mean                141530 non-null  float64
#  26  Bwd IAT Std                 141530 non-null  float64
#  27  Bwd IAT Max                 141530 non-null  int64
#  28  Bwd IAT Min                 141530 non-null  int64
#  29  Fwd PSH Flags               141530 non-null  int64
#  30  Bwd PSH Flags               141530 non-null  int64
#  31  Fwd URG Flags               141530 non-null  int64
#  32  Bwd URG Flags               141530 non-null  int64
#  33  Fwd Header Length           141530 non-null  int64
#  34  Bwd Header Length           141530 non-null  int64
#  35  Fwd Packets/s               141530 non-null  float64
#  36  Bwd Packets/s               141530 non-null  float64
#  37  Packet Length Min           141530 non-null  int64
#  38  Packet Length Max           141530 non-null  int64
#  39  Packet Length Mean          141530 non-null  float64
#  40  Packet Length Std           141530 non-null  float64
#  41  Packet Length Variance      141530 non-null  float64
#  42  FIN Flag Count              141530 non-null  int64
#  43  SYN Flag Count              141530 non-null  int64
#  44  RST Flag Count              141530 non-null  int64
#  45  PSH Flag Count              141530 non-null  int64
#  46  ACK Flag Count              141530 non-null  int64
#  47  URG Flag Count              141530 non-null  int64
#  48  CWE Flag Count              141530 non-null  int64
#  49  ECE Flag Count              141530 non-null  int64
#  50  Down/Up Ratio               141530 non-null  int64
#  51  Average Packet Size         141530 non-null  float64
#  52  Fwd Segment Size Avg        141530 non-null  float64
#  53  Bwd Segment Size Avg        141530 non-null  float64
#  54  Fwd Bytes/Bulk Avg          141530 non-null  int64
#  55  Fwd Packet/Bulk Avg         141530 non-null  int64
#  56  Fwd Bulk Rate Avg           141530 non-null  int64
#  57  Bwd Bytes/Bulk Avg          141530 non-null  int64
#  58  Bwd Packet/Bulk Avg         141530 non-null  int64
#  59  Bwd Bulk Rate Avg           141530 non-null  int64
#  60  Subflow Fwd Packets         141530 non-null  int64
#  61  Subflow Fwd Bytes           141530 non-null  int64
#  62  Subflow Bwd Packets         141530 non-null  int64
#  63  Subflow Bwd Bytes           141530 non-null  int64
#  64  FWD Init Win Bytes          141530 non-null  int64
#  65  Bwd Init Win Bytes          141530 non-null  int64
#  66  Fwd Act Data Pkts           141530 non-null  int64
#  67  Fwd Seg Size Min            141530 non-null  int64
#  68  Active Mean                 141530 non-null  int64
#  69  Active Std                  141530 non-null  int64
#  70  Active Max                  141530 non-null  int64
#  71  Active Min                  141530 non-null  int64
#  72  Idle Mean                   141530 non-null  float64
#  73  Idle Std                    141530 non-null  float64
#  74  Idle Max                    141530 non-null  float64
#  75  Idle Min                    141530 non-null  float64
#  76  Level1                      141530 non-null  object
#  77  Level2                      141530 non-null  object
# dtypes: float64(24), int64(52), object(2)
# memory usage: 84.2+ MB
#         Protocol  Total Fwd Packet  Total Bwd packets  \
# 141525        17                 2                  0
# 141526        17                 2                  0
# 141527        17                 2                  0
# 141528        17                 2                  0
# 141529        17              5995               6000
#
#         Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 141525                          44                           0
# 141526                          44                           0
# 141527                          44                           0
# 141528                          44                           0
# 141529                      497585                      498000
#
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 141525                     22                     22                    22.0
# 141526                     22                     22                    22.0
# 141527                     22                     22                    22.0
# 141528                     22                     22                    22.0
# 141529                     83                     83                    83.0
#
#         Fwd Packet Length Std  Bwd Packet Length Max  Bwd Packet Length Min  \
# 141525                    0.0                      0                      0
# 141526                    0.0                      0                      0
# 141527                    0.0                      0                      0
# 141528                    0.0                      0                      0
# 141529                    0.0                     83                     83
#
#         Bwd Packet Length Mean  Bwd Packet Length Std  Flow Bytes/s  \
# 141525                     0.0                    0.0    106.846428
# 141526                     0.0                    0.0    106.906656
# 141527                     0.0                    0.0    104.191580
# 141528                     0.0                    0.0    106.833716
# 141529                    83.0                    0.0   8297.230060
#
#         Flow Packets/s  Flow IAT Mean  Flow IAT Std  Flow IAT Max  \
# 141525        4.856656   411806.00000      0.000000        411806
# 141526        4.859393   411574.00000      0.000000        411574
# 141527        4.735981   422299.00000      0.000000        422299
# 141528        4.856078   411855.00000      0.000000        411855
# 141529       99.966627    10004.17242   6062.617783         24192
#
#         Flow IAT Min  Fwd IAT Total   Fwd IAT Mean  Fwd IAT Std  Fwd IAT Max  \
# 141525        411806         411806  411806.000000     0.000000       411806
# 141526        411574         411574  411574.000000     0.000000       411574
# 141527        422299         422299  422299.000000     0.000000       422299
# 141528        411855         411855  411855.000000     0.000000       411855
# 141529            48      119976697   20016.132299  4563.211794        84684
#
#         Fwd IAT Min  Bwd IAT Total  Bwd IAT Mean  Bwd IAT Std  Bwd IAT Max  \
# 141525       411806              0       0.00000     0.000000            0
# 141526       411574              0       0.00000     0.000000            0
# 141527       422299              0       0.00000     0.000000            0
# 141528       411855              0       0.00000     0.000000            0
# 141529           86      119988870   20001.47858  3396.391469        25437
#
#         Bwd IAT Min  Fwd PSH Flags  Bwd PSH Flags  Fwd URG Flags  \
# 141525            0              0              0              0
# 141526            0              0              0              0
# 141527            0              0              0              0
# 141528            0              0              0              0
# 141529         5780              0              0              0
#
#         Bwd URG Flags  Fwd Header Length  Bwd Header Length  Fwd Packets/s  \
# 141525              0                 16                  0       4.856656
# 141526              0                 16                  0       4.859393
# 141527              0                 16                  0       4.735981
# 141528              0                 16                  0       4.856078
# 141529              0              47960              48000      49.962479
#
#         Bwd Packets/s  Packet Length Min  Packet Length Max  \
# 141525       0.000000                 22                 22
# 141526       0.000000                 22                 22
# 141527       0.000000                 22                 22
# 141528       0.000000                 22                 22
# 141529      50.004149                 83                 83
#
#         Packet Length Mean  Packet Length Std  Packet Length Variance  \
# 141525                22.0                0.0                     0.0
# 141526                22.0                0.0                     0.0
# 141527                22.0                0.0                     0.0
# 141528                22.0                0.0                     0.0
# 141529                83.0                0.0                     0.0
#
#         FIN Flag Count  SYN Flag Count  RST Flag Count  PSH Flag Count  \
# 141525               0               0               0               0
# 141526               0               0               0               0
# 141527               0               0               0               0
# 141528               0               0               0               0
# 141529               0               0               0               0
#
#         ACK Flag Count  URG Flag Count  CWE Flag Count  ECE Flag Count  \
# 141525               0               0               0               0
# 141526               0               0               0               0
# 141527               0               0               0               0
# 141528               0               0               0               0
# 141529               0               0               0               0
#
#         Down/Up Ratio  Average Packet Size  Fwd Segment Size Avg  \
# 141525              0             33.00000                  22.0
# 141526              0             33.00000                  22.0
# 141527              0             33.00000                  22.0
# 141528              0             33.00000                  22.0
# 141529              1             83.00692                  83.0
#
#         Bwd Segment Size Avg  Fwd Bytes/Bulk Avg  Fwd Packet/Bulk Avg  \
# 141525                   0.0                   0                    0
# 141526                   0.0                   0                    0
# 141527                   0.0                   0                    0
# 141528                   0.0                   0                    0
# 141529                  83.0                   0                    0
#
#         Fwd Bulk Rate Avg  Bwd Bytes/Bulk Avg  Bwd Packet/Bulk Avg  \
# 141525                  0                   0                    0
# 141526                  0                   0                    0
# 141527                  0                   0                    0
# 141528                  0                   0                    0
# 141529                  0                   0                11995
#
#         Bwd Bulk Rate Avg  Subflow Fwd Packets  Subflow Fwd Bytes  \
# 141525                  0                    1                 22
# 141526                  0                    1                 22
# 141527                  0                    1                 22
# 141528                  0                    1                 22
# 141529               8297                    0                 41
#
#         Subflow Bwd Packets  Subflow Bwd Bytes  FWD Init Win Bytes  \
# 141525                    0                  0                   0
# 141526                    0                  0                   0
# 141527                    0                  0                   0
# 141528                    0                  0                   0
# 141529                    0                 41                   0
#
#         Bwd Init Win Bytes  Fwd Act Data Pkts  Fwd Seg Size Min  Active Mean  \
# 141525                   0                  1                 8            0
# 141526                   0                  1                 8            0
# 141527                   0                  1                 8            0
# 141528                   0                  1                 8            0
# 141529                   0               5994                 8            0
#
#         Active Std  Active Max  Active Min     Idle Mean      Idle Std  \
# 141525           0           0           0  0.000000e+00  0.000000e+00
# 141526           0           0           0  0.000000e+00  0.000000e+00
# 141527           0           0           0  0.000000e+00  0.000000e+00
# 141528           0           0           0  0.000000e+00  0.000000e+00
# 141529           0           0           0  1.432316e+15  3.463689e+07
#
#             Idle Max      Idle Min Level1 Level2
# 141525  0.000000e+00  0.000000e+00    VPN   VOIP
# 141526  0.000000e+00  0.000000e+00    VPN   VOIP
# 141527  0.000000e+00  0.000000e+00    VPN   VOIP
# 141528  0.000000e+00  0.000000e+00    VPN   VOIP
# 141529  1.432316e+15  1.432316e+15    VPN   VOIP

# %%
start_mem = data.memory_usage().sum() / 1024**2 # start mem for comparison later

for col in data.columns:
    col_type = data[col].dtypes
    if col_type in ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']:
        c_min = data[col].min()
        c_max = data[col].max()
        if str(col_type)[:3] == 'int': # if it's int
            if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max: # if it can be int8, make it int8
                data[col] = data[col].astype(np.int8)
            elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max: # if it can be int16, make it int16
                data[col] = data[col].astype(np.int16)
            elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max: # so on
                data[col] = data[col].astype(np.int32)
            elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                data[col] = data[col].astype(np.int64)
        else: # if it's float
            if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max: # if it can be float16, make it float16
                data[col] = data[col].astype(np.float16)
            elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max: # so on
                data[col] = data[col].astype(np.float32)
            else:
                data[col] = data[col].astype(np.float64)

end_mem = data.memory_usage().sum() / 1024**2 # end mem for comparison later

print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
# Out:
# Memory usage after optimization is: 31.31 MB
# Decreased by 62.8%

# %%
display_all(data.tail())
# Out:
# The shape is:  (141530, 78)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141530 entries, 0 to 141529
# Data columns (total 78 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Protocol                    141530 non-null  int8
#  1   Total Fwd Packet            141530 non-null  int32
#  2   Total Bwd packets           141530 non-null  int32
#  3   Total Length of Fwd Packet  141530 non-null  int32
#  4   Total Length of Bwd Packet  141530 non-null  int32
#  5   Fwd Packet Length Max       141530 non-null  int32
#  6   Fwd Packet Length Min       141530 non-null  int16
#  7   Fwd Packet Length Mean      141530 non-null  float16
#  8   Fwd Packet Length Std       141530 non-null  float16
#  9   Bwd Packet Length Max       141530 non-null  int32
#  10  Bwd Packet Length Min       141530 non-null  int16
#  11  Bwd Packet Length Mean      141530 non-null  float16
#  12  Bwd Packet Length Std       141530 non-null  float16
#  13  Flow Bytes/s                141483 non-null  float64
#  14  Flow Packets/s              141530 non-null  float64
#  15  Flow IAT Mean               141530 non-null  float32
#  16  Flow IAT Std                141530 non-null  float32
#  17  Flow IAT Max                141530 non-null  int32
#  18  Flow IAT Min                141530 non-null  int32
#  19  Fwd IAT Total               141530 non-null  int32
#  20  Fwd IAT Mean                141530 non-null  float32
#  21  Fwd IAT Std                 141530 non-null  float32
#  22  Fwd IAT Max                 141530 non-null  int32
#  23  Fwd IAT Min                 141530 non-null  int32
#  24  Bwd IAT Total               141530 non-null  int32
#  25  Bwd IAT Mean                141530 non-null  float32
#  26  Bwd IAT Std                 141530 non-null  float32
#  27  Bwd IAT Max                 141530 non-null  int32
#  28  Bwd IAT Min                 141530 non-null  int32
#  29  Fwd PSH Flags               141530 non-null  int8
#  30  Bwd PSH Flags               141530 non-null  int8
#  31  Fwd URG Flags               141530 non-null  int8
#  32  Bwd URG Flags               141530 non-null  int8
#  33  Fwd Header Length           141530 non-null  int32
#  34  Bwd Header Length           141530 non-null  int32
#  35  Fwd Packets/s               141530 non-null  float32
#  36  Bwd Packets/s               141530 non-null  float32
#  37  Packet Length Min           141530 non-null  int16
#  38  Packet Length Max           141530 non-null  int32
#  39  Packet Length Mean          141530 non-null  float16
#  40  Packet Length Std           141530 non-null  float16
#  41  Packet Length Variance      141530 non-null  float32
#  42  FIN Flag Count              141530 non-null  int8
#  43  SYN Flag Count              141530 non-null  int8
#  44  RST Flag Count              141530 non-null  int8
#  45  PSH Flag Count              141530 non-null  int32
#  46  ACK Flag Count              141530 non-null  int32
#  47  URG Flag Count              141530 non-null  int8
#  48  CWE Flag Count              141530 non-null  int8
#  49  ECE Flag Count              141530 non-null  int8
#  50  Down/Up Ratio               141530 non-null  int16
#  51  Average Packet Size         141530 non-null  float16
#  52  Fwd Segment Size Avg        141530 non-null  float16
#  53  Bwd Segment Size Avg        141530 non-null  float16
#  54  Fwd Bytes/Bulk Avg          141530 non-null  int8
#  55  Fwd Packet/Bulk Avg         141530 non-null  int8
#  56  Fwd Bulk Rate Avg           141530 non-null  int8
#  57  Bwd Bytes/Bulk Avg          141530 non-null  int8
#  58  Bwd Packet/Bulk Avg         141530 non-null  int32
#  59  Bwd Bulk Rate Avg           141530 non-null  int32
#  60  Subflow Fwd Packets         141530 non-null  int8
#  61  Subflow Fwd Bytes           141530 non-null  int16
#  62  Subflow Bwd Packets         141530 non-null  int8
#  63  Subflow Bwd Bytes           141530 non-null  int16
#  64  FWD Init Win Bytes          141530 non-null  int32
#  65  Bwd Init Win Bytes          141530 non-null  int32
#  66  Fwd Act Data Pkts           141530 non-null  int32
#  67  Fwd Seg Size Min            141530 non-null  int8
#  68  Active Mean                 141530 non-null  int8
#  69  Active Std                  141530 non-null  int8
#  70  Active Max                  141530 non-null  int8
#  71  Active Min                  141530 non-null  int8
#  72  Idle Mean                   141530 non-null  float32
#  73  Idle Std                    141530 non-null  float32
#  74  Idle Max                    141530 non-null  float32
#  75  Idle Min                    141530 non-null  float32
#  76  Level1                      141530 non-null  object
#  77  Level2                      141530 non-null  object
# dtypes: float16(9), float32(13), float64(2), int16(6), int32(24), int8(22), object(2)
# memory usage: 31.3+ MB
#         Protocol  Total Fwd Packet  Total Bwd packets  \
# 141525        17                 2                  0
# 141526        17                 2                  0
# 141527        17                 2                  0
# 141528        17                 2                  0
# 141529        17              5995               6000
#
#         Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 141525                          44                           0
# 141526                          44                           0
# 141527                          44                           0
# 141528                          44                           0
# 141529                      497585                      498000
#
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 141525                     22                     22                    22.0
# 141526                     22                     22                    22.0
# 141527                     22                     22                    22.0
# 141528                     22                     22                    22.0
# 141529                     83                     83                    83.0
#
#         Fwd Packet Length Std  Bwd Packet Length Max  Bwd Packet Length Min  \
# 141525                    0.0                      0                      0
# 141526                    0.0                      0                      0
# 141527                    0.0                      0                      0
# 141528                    0.0                      0                      0
# 141529                    0.0                     83                     83
#
#         Bwd Packet Length Mean  Bwd Packet Length Std  Flow Bytes/s  \
# 141525                     0.0                    0.0    106.846428
# 141526                     0.0                    0.0    106.906656
# 141527                     0.0                    0.0    104.191580
# 141528                     0.0                    0.0    106.833716
# 141529                    83.0                    0.0   8297.230060
#
#         Flow Packets/s  Flow IAT Mean  Flow IAT Std  Flow IAT Max  \
# 141525        4.856656  411806.000000      0.000000        411806
# 141526        4.859393  411574.000000      0.000000        411574
# 141527        4.735981  422299.000000      0.000000        422299
# 141528        4.856078  411855.000000      0.000000        411855
# 141529       99.966627   10004.172852   6062.617676         24192
#
#         Flow IAT Min  Fwd IAT Total   Fwd IAT Mean  Fwd IAT Std  Fwd IAT Max  \
# 141525        411806         411806  411806.000000     0.000000       411806
# 141526        411574         411574  411574.000000     0.000000       411574
# 141527        422299         422299  422299.000000     0.000000       422299
# 141528        411855         411855  411855.000000     0.000000       411855
# 141529            48      119976697   20016.132812  4563.211914        84684
#
#         Fwd IAT Min  Bwd IAT Total  Bwd IAT Mean  Bwd IAT Std  Bwd IAT Max  \
# 141525       411806              0      0.000000     0.000000            0
# 141526       411574              0      0.000000     0.000000            0
# 141527       422299              0      0.000000     0.000000            0
# 141528       411855              0      0.000000     0.000000            0
# 141529           86      119988870  20001.478516  3396.391357        25437
#
#         Bwd IAT Min  Fwd PSH Flags  Bwd PSH Flags  Fwd URG Flags  \
# 141525            0              0              0              0
# 141526            0              0              0              0
# 141527            0              0              0              0
# 141528            0              0              0              0
# 141529         5780              0              0              0
#
#         Bwd URG Flags  Fwd Header Length  Bwd Header Length  Fwd Packets/s  \
# 141525              0                 16                  0       4.856656
# 141526              0                 16                  0       4.859394
# 141527              0                 16                  0       4.735981
# 141528              0                 16                  0       4.856078
# 141529              0              47960              48000      49.962479
#
#         Bwd Packets/s  Packet Length Min  Packet Length Max  \
# 141525        0.00000                 22                 22
# 141526        0.00000                 22                 22
# 141527        0.00000                 22                 22
# 141528        0.00000                 22                 22
# 141529       50.00415                 83                 83
#
#         Packet Length Mean  Packet Length Std  Packet Length Variance  \
# 141525                22.0                0.0                     0.0
# 141526                22.0                0.0                     0.0
# 141527                22.0                0.0                     0.0
# 141528                22.0                0.0                     0.0
# 141529                83.0                0.0                     0.0
#
#         FIN Flag Count  SYN Flag Count  RST Flag Count  PSH Flag Count  \
# 141525               0               0               0               0
# 141526               0               0               0               0
# 141527               0               0               0               0
# 141528               0               0               0               0
# 141529               0               0               0               0
#
#         ACK Flag Count  URG Flag Count  CWE Flag Count  ECE Flag Count  \
# 141525               0               0               0               0
# 141526               0               0               0               0
# 141527               0               0               0               0
# 141528               0               0               0               0
# 141529               0               0               0               0
#
#         Down/Up Ratio  Average Packet Size  Fwd Segment Size Avg  \
# 141525              0                 33.0                  22.0
# 141526              0                 33.0                  22.0
# 141527              0                 33.0                  22.0
# 141528              0                 33.0                  22.0
# 141529              1                 83.0                  83.0
#
#         Bwd Segment Size Avg  Fwd Bytes/Bulk Avg  Fwd Packet/Bulk Avg  \
# 141525                   0.0                   0                    0
# 141526                   0.0                   0                    0
# 141527                   0.0                   0                    0
# 141528                   0.0                   0                    0
# 141529                  83.0                   0                    0
#
#         Fwd Bulk Rate Avg  Bwd Bytes/Bulk Avg  Bwd Packet/Bulk Avg  \
# 141525                  0                   0                    0
# 141526                  0                   0                    0
# 141527                  0                   0                    0
# 141528                  0                   0                    0
# 141529                  0                   0                11995
#
#         Bwd Bulk Rate Avg  Subflow Fwd Packets  Subflow Fwd Bytes  \
# 141525                  0                    1                 22
# 141526                  0                    1                 22
# 141527                  0                    1                 22
# 141528                  0                    1                 22
# 141529               8297                    0                 41
#
#         Subflow Bwd Packets  Subflow Bwd Bytes  FWD Init Win Bytes  \
# 141525                    0                  0                   0
# 141526                    0                  0                   0
# 141527                    0                  0                   0
# 141528                    0                  0                   0
# 141529                    0                 41                   0
#
#         Bwd Init Win Bytes  Fwd Act Data Pkts  Fwd Seg Size Min  Active Mean  \
# 141525                   0                  1                 8            0
# 141526                   0                  1                 8            0
# 141527                   0                  1                 8            0
# 141528                   0                  1                 8            0
# 141529                   0               5994                 8            0
#
#         Active Std  Active Max  Active Min     Idle Mean    Idle Std  \
# 141525           0           0           0  0.000000e+00         0.0
# 141526           0           0           0  0.000000e+00         0.0
# 141527           0           0           0  0.000000e+00         0.0
# 141528           0           0           0  0.000000e+00         0.0
# 141529           0           0           0  1.432316e+15  34636892.0
#
#             Idle Max      Idle Min Level1 Level2
# 141525  0.000000e+00  0.000000e+00    VPN   VOIP
# 141526  0.000000e+00  0.000000e+00    VPN   VOIP
# 141527  0.000000e+00  0.000000e+00    VPN   VOIP
# 141528  0.000000e+00  0.000000e+00    VPN   VOIP
# 141529  1.432316e+15  1.432316e+15    VPN   VOIP

# %%
# scaler = StandardScaler().fit(model_samples[real_columns])
# model_samples[real_columns] = scaler.transform(model_samples[real_columns])
# model_samples[real_columns].head()
# samples = samples.dropna()
# model_samples = model_samples.dropna()
# print(samples[samples.columns[samples.isna().sum()>0]].isna().sum())

# %% [markdown]
# # Split

# %%
copied = data.copy()

# %%
"""
Inputs for all values other than Non-Tor had nan values so cannot just drop them, filling with mean instead
"""
# Out:
# '\nInputs for all values other than Non-Tor had nan values so cannot just drop them, filling with mean instead\n'

# %%
#replacing inf and null values with mean
copied.replace([np.inf, -np.inf], np.nan, inplace=True)
copied = copied.fillna(copied.mean())
# Out:
# C:\Users\AmirHosein\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:90: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\AmirHosein\anaconda3\lib\site-packages\numpy\core\_methods.py:38: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)

# %%
copied.isnull().sum().sum()
# Out:
# 0

# %%
copied = copied[(copied.Level1 == 'Tor') | (copied.Level1 == 'Non-Tor')]      #Dropping classes other than Tor and Non-Tor

# %%
Y = copied[["Level1", "Level2"]]
X = copied.drop(["Level1", "Level2"], axis=1)

# %%
Y
# Out:
#          Level1           Level2
# 0       Non-Tor  Audio-Streaming
# 1       Non-Tor  Audio-Streaming
# 2       Non-Tor  Audio-Streaming
# 3       Non-Tor  Audio-Streaming
# 4       Non-Tor  Audio-Streaming
# ...         ...              ...
# 118606      Tor  Video-Streaming
# 118607      Tor  Video-Streaming
# 118608      Tor  Video-Streaming
# 118609      Tor  Video-Streaming
# 118610      Tor  Video-Streaming
#
# [94748 rows x 2 columns]

# %%
X.isnull().sum().sum()
# Out:
# 0

# %%
Y.isnull().sum().sum()
# Out:
# 0

# %%
Y.replace('Tor', 1, inplace=True)               #Converting strings to binary classes 0 or 1
Y.replace('Non-Tor', 0, inplace=True)
# Out:
# C:\Users\AmirHosein\anaconda3\lib\site-packages\pandas\core\frame.py:4166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
# FEATURE EXTRACTION

# from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
# count_vect = CountVectorizer(stop_words='english')
# transformer = TfidfTransformer(sublinear_tf=True)

# X_train_cnt = count_vect.fit_transform(X_train)
# X_train_TF = transformer.fit_transform(X_train_cnt)
# print(X_train_cnt.shape)
# print(X_train_TF.shape)

# X_test_cnt = count_vect.transform(X_test)
# X_test_TF = transformer.transform(X_test_cnt)
# print(X_test_cnt.shape)
# print(X_test_TF.shape)

# %%
#Using only the first classification for the gridsearch
Y_train_l = Y_train['Level1']
Y_test_l = Y_test['Level1']

# %%
Y_train_l
# Out:
# 48981    0
# 22171    0
# 49198    0
# 43608    0
# 56134    0
#         ..
# 6265     0
# 54886    0
# 76820    0
# 860      0
# 15795    0
# Name: Level1, Length: 66323, dtype: int64

# %%
Y_train_l.value_counts() #value counts to check for imbalance
# Out:
# 0    65335
# 1      988
# Name: Level1, dtype: int64

# %%
#importing libraries for models
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier, BaggingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as impip
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold

# %%
#Creating classifiers to be passed to the pipeline
clf1 = RandomForestClassifier(random_state=42, criterion = 'entropy')
clf2 = ExtraTreesClassifier(random_state=42, criterion = 'entropy')
clf3 = DecisionTreeClassifier(random_state=42, criterion = 'entropy')
clf4 = GradientBoostingClassifier(random_state=42)
clf5 = AdaBoostClassifier(random_state=42)
clf6 = BaggingClassifier(random_state=42)
clf7 = SVC(random_state=42)

# %%
#Initializing parameter dictionary for models

param1 = {}
param1['classifier__n_estimators'] = [10, 50, 100]
param1['classifier__max_depth'] = [5, 10, 20]
param1['classifier__min_samples_split'] = [2,5,10]
param1['classifier'] = [clf1]

param2 = {}
param2['classifier__n_estimators'] = [10, 50, 100]
param2['classifier__max_depth'] = [5, 10, 20]
param2['classifier__min_samples_split'] = [2,5,10]
param2['classifier'] = [clf2]

param3 = {}
param3['classifier__max_depth'] = [5, 10, 20]
param3['classifier__min_samples_split'] = [2,5,10]
param3['classifier'] = [clf3]

param4 = {}
param4['classifier__n_estimators'] = [10, 50, 100]
param4['classifier__learning_rate'] = [0.01, 0.05, 0.1]
param4['classifier__max_depth'] = [5, 10, 20]
param3['classifier__min_samples_split'] = [2,5,10]
param4['classifier'] = [clf4]

param5 = {}
param5['classifier__n_estimators'] = [10, 50, 100]
param5['classifier__learning_rate'] = [0.01, 0.05, 0.1]
param5['classifier'] = [clf5]

param6 = {}
param6['classifier__n_estimators'] = [10, 50, 100]
param6['classifier__max_samples'] = [0.05, 0.1, 0.2, 0.5]
param6['classifier'] = [clf6]

param7 = {}
param7['classifier__C'] = [0.01, 0.1, 1, 5]
param7['classifier__kernel'] = ['linear', 'rbf', 'sigmoid']
param7['classifier'] = [clf7]

params = [param1, param2, param3, param4, param5, param6, param7]

# %%
#Creating random_state=ne for the models
pipeline = impip([('scaler', StandardScaler()),('smot',SMOTE(random_state=12)),('selection',PCA()) ,('classifier', clf1),])

# %%
#implementing randomized search because gridsearch takes forever
rs = RandomizedSearchCV(pipeline, params, cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=123), n_jobs=-1, scoring='f1', error_score='raise').fit(X_train, Y_train_l)
rs.best_params_

# %%
rs.best_score_
# Out:
# 0.999788913659172

# %%
# #Running gridsearch for the models and params to get the best params
# grid = GridSearchCV(pipeline, params, cv=3, n_jobs=-1, scoring='f1').fit(X_train, Y_train_l)
# grid.best_params_

# %%
grid.best_score_

# %%
#Testing gridsearch using accuracy
accuracy_score(grid.predict(X_test), Y_test_l)

# %%
ranForModel = RandomForestClassifier(n_estimators=10, criterion = "entropy")
ranForModel.fit(X_train, Y_train_l)
ranpred = ranForModel.predict(X_test)
Accuracy = accuracy_score(Y_test_l, ranpred)
Accuracy

# %% [markdown]
# ## Step 2: Classifying the Tor observations

# %%
def categorise(row):
    if row['Level1'] == 1:
        return f"Tor {row['Level2']}"
    else:
        return 'Non-Tor'

# %%
Y['category'] = Y.apply(lambda row: categorise(row), axis = 1)
# Out:
# /tmp/ipykernel_689/3223523636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y['category'] = Y.apply(lambda row: categorise(row), axis = 1)

# %%
Y['category'].value_counts()
# Out:
# Non-Tor                93356
# Tor VOIP                 298
# Tor Browsing             263
# Tor Audio-Streaming      224
# Tor P2P                  220
# Tor Video-Streaming      202
# Tor File-Transfer        107
# Tor Chat                  65
# Tor Email                 13
# Name: category, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
ye = list(Y['category'])

# %%
ds = le.fit_transform(ye)

# %%
pd.Series(ds).value_counts()
# Out:
# 0    93356
# 7      298
# 2      263
# 1      224
# 6      220
# 8      202
# 5      107
# 3       65
# 4       13
# dtype: int64

# %%
Y1 = pd.DataFrame(ds)

# %%
Y1.rename(columns = {0 : "Level_2"}, inplace = True)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y1, test_size=0.30, random_state=42)

# %%
#importing libraries for models
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier, BaggingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
#Creating classifiers to be passed to the pipeline
models = list()
models.append(('rfc', RandomForestClassifier(random_state=42, criterion = 'entropy')))
models.append(('etc', ExtraTreesClassifier(random_state=42, criterion = 'entropy')))
models.append(('dtc', DecisionTreeClassifier(random_state=42, criterion = 'entropy')))
models.append(('gbc', GradientBoostingClassifier(random_state=42)))
models.append(('abc', AdaBoostClassifier(random_state=42)))
models.append(('bc', BaggingClassifier(random_state=42)))
models.append(('svm', SVC(random_state=42)))

# %%
from sklearn.ensemble import VotingClassifier

ensemble = VotingClassifier(estimators=models, voting='hard')

# %%
ensemble.fit(X_train, Y_train)
# Out:
# /home/godwin/.pyenv/versions/3.8.15/lib/python3.8/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/godwin/.pyenv/versions/3.8.15/lib/python3.8/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# VotingClassifier(estimators=[('rfc',
#                               RandomForestClassifier(criterion='entropy',
#                                                      random_state=42)),
#                              ('etc',
#                               ExtraTreesClassifier(criterion='entropy',
#                                                    random_state=42)),
#                              ('dtc',
#                               DecisionTreeClassifier(criterion='entropy',
#                                                      random_state=42)),
#                              ('gbc',
#                               GradientBoostingClassifier(random_state=42)),
#                              ('abc', AdaBoostClassifier(random_state=42)),
#                              ('bc', BaggingClassifier(random_state=42)),
#                              ('svm', SVC(random_state=42))])

# %%
accuracy_score(ensemble.predict(X_test), Y_test)
# Out:
# 0.9980299032541776

# %%
from sklearn.metrics import f1_score, classification_report

output = ensemble.predict(X_test)
print("F1 score",f1_score(Y_test, output, average=None))
print(classification_report(Y_test, output, target_names=['0','1','2','3','4','5','6','7','8']))
# Out:
# F1 score [0.99994647 0.88888889 0.84210526 0.74285714 0.75       0.8125
#  0.96062992 0.89772727 0.78181818]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28021
#            1       0.83      0.95      0.89        63
#            2       0.88      0.81      0.84        79
#            3       0.76      0.72      0.74        18
#            4       0.75      0.75      0.75         4
#            5       0.90      0.74      0.81        35
#            6       0.92      1.00      0.96        61
#            7       0.95      0.85      0.90        93
#            8       0.73      0.84      0.78        51
#
#     accuracy                           1.00     28425
#    macro avg       0.86      0.85      0.85     28425
# weighted avg       1.00      1.00      1.00     28425

# %%
Y_test.value_counts()
# Out:
# Level_2
# 0          28021
# 7             93
# 2             79
# 1             63
# 6             61
# 8             51
# 5             35
# 3             18
# 4              4
# dtype: int64
